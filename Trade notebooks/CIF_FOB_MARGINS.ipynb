# %%
import pandas as pd
import numpy as np

# %%
year_to_filter = 2022
chunks = pd.read_csv('/content/drive/MyDrive/Trade project data/oecd data/OECD_ITIC2024_bulkfile.csv', usecols=['reporter', 'partner', 'product', 'year', 'margin'], chunksize=100000)
filtered_data = pd.concat([chunk[chunk['year'] == year_to_filter] for chunk in chunks])

# %%
filtered_data.head()
# Out:
#     reporter partner    product  year  margin
# 513      BGR     ABW  HS17_2713  2022   16.13
# 514      BGR     ABW  HS17_3305  2022   11.84
# 515      BGR     ABW  HS17_3923  2022   14.18
# 516      BGR     ABW  HS17_3926  2022   13.10
# 517      BGR     ABW  HS17_5407  2022   12.00

# %%
filtered_data['product'].unique()
# Out:
# array(['HS17_2713', 'HS17_3305', 'HS17_3923', ..., 'HS17_9302',
#        'HS17_9999', '_T'], dtype=object)

# %%
# Assuming 'product' column contains strings representing product codes
filtered_data['product'] = filtered_data['product'].astype(str).str[5:]

filtered_data.head()
filtered_data['product'].unique()
# Out:
# array(['2713', '3305', '3923', ..., '9302', '9999', ''], dtype=object)

# %%
filtered_data.sort_values(by='product', ascending=False, inplace=True)

# %%
filtered_data.to_csv('/content/drive/MyDrive/Trade project data/Trasport margins/transport_2022.csv', index=False)
